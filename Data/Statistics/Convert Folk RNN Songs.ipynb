# %% [markdown]
# ## Convert Folk RNN samples to vectors

# %%
songs = \
[ 
    '|:cBAG EFG2|ABcA GEC2|F2EF DEF2|EDCE F2E2|cBAG EFG2|ABcA GEC2|FEFG AGEC|DEFD C4:| |:EFGA BGAB|cBcd ecGE|F2AF EFGE|FEDC D2GF EFGA BGAB|cBcd ecGF|EFGA BGF2|DFED C4:|',
    '|:e2dc ecdc|AFEF DCDF|EGAG cGAc|Fdcd dcAG|e2dc ecdc|AGAF ECDF|EGAG FAcf|ecdB c2c2:||:egg2 afge|cedc Bcdf|efge fedc|AGAB cdcB|c3d cBAG|EGAB cdeg|f3g fedc|BcdB c2c2:|',
    'C E G c B c | A G F E D C | C E G c B c | d B G A G F | C E G c B c | A G F E D C | C 2 E G F E | D E C C 3 :| |: g e g f d f | e c e d B G | c B c G E G | B c A G E C | e g e f d f | e c d B G F | G E G F A F | E G E C 2 C :|',
    'C 2 E C E C G, 2 | B 2 B D B, G, D B, | C 2 E C E G C E | D C B, C D C C 2 :| C 2 E C G C E C | F 2 D B, B, D G, B, | C 2 E C G C E C | F D D C B, C G, B, | C 2 E C G C E C | F 2 D F B, D F D | E C G C E C G E | F D B, D C 2 |',
    ' c 2 G F E 2 C E | D 2 G 2 E 2 C 2 | E 2 G E F 2 D 2 | E 2 C 2 C 2 :| |: c 2 | E G C E G 2 E G | G 2 F 2 A 2 D 2 | F E D C B 2 G 2 | A 2 G 2 E 2 D 2 | C E G C E 2 G 2 | C 2 E F G 2 G 2 | A 2 A 2 G 2 E 2 | D 4 C 2 :|',
    'G 2 G F E C C 2 | G c c B c d c A | G 2 G F E C C f | e c d B G A A 2 | G 2 c B G C C 2 | G c e c d c c 2 | G c c A G E E 2 | F E D E C 4 :| |: E F G A G E E 2 | c 2 B c d e e d | c B c A G 2 E E | E 2 G E D E D F | E F G A G E E 2 | c e d c B c G 2 | A F F 2 G E E 2 | G 2 d g e c c 2 :|',
    '|: E C E C E G G 2 | c 2 e c d c A c | E C E C E 2 G 2 | c A G E D F E D | C E E 2 C 2 E G | c G e c d e e f | g e c e f 2 a f | f e d c d c A 2 :| |: c G A F G F E F | G c c B c 2 c d | e c c B G F E G | A d d c d e f d | e f g e f e d c | G c c B c d e f | g e f d e c d B | c A G E F 2 G F :|',
    '| E 2 G E C E G E | F A d c B G A B | c 2 G E C E G E | F G A B c A G F | E 2 G E C E G E | F A F D D E F D | E A A G E 3 F | G A B d c 2 :| |: E F | G c c B c 3 B | c d e c d 2 B G | c B c d e g e c | d e d c B G G E | G c c B c 2 G 2 | c d c B G A B c | d c B c d e f d | e c c B c 2 :|',
    '|C2C2 C2E2|DEDC A,2G,2|E2ED E2E2| DEDC A,2G,2|C2C2 E2E2|DEDC A,2G,2|E2E2 D2E2| DCD2 C2:||:EF|G2G2 G2AB|c2B2 A2B2| c2B2 A2G2|A2A2 G2E2|G2G2 G2AB|c2B2 A2G2| c2B2 A2G2|E2D2 CD:',
    'CEce dgBG|FECE F_B,DF|CEGE Fccd| cBcA GAGF|EGce gfed|cGFE FAGF|EGcG FEFE| D_B,G,B, C2:|zC|CEcd eg^fe|dBGF EGcd| ecge fdBG|ced_B GABG|cBce dcBA|GBcA BGFE| Acdc BGAF|GFED C2:|',
    'ECDC A,G,C2|ECDC A,G,CD|ECDC AGED|CEDE CA,G,2| ECDC A,CCA,|ECDC A,CEF|GEFD ECCB,|CA,G,A, C2CD:| EGGA GEDC|EGAB c3B|AGEC DECD|EEDE C2CD| EGAB cAGE|EGAB c2dc|BcdB GAAG|EDEC D2CA,:|',
    'G,CA,C CEGB|cBAG ABcA|GEE2 CCED|ECDE CB,A,G,| G,CCB, CEGB|cBAG ABcd|ecdB cBAG|(3EFGDE CA,G,A,| G,EE2 CEGc|(3ABAGE DECA,|G,EE2 CEGc|ACDE CA,A,2| G,EE2 CEGc|ABcA GECE|GEE2 DECA,|G,CEC DCA,/2B,/2C|'
    'GFFG CDEF|G2Ac dcAc|GFDE FDEF| G2AB cABc|GFEG CDEF|G2Ac dcAc|G2FG CGEG| FDDF ECC:|f|ecc2 dcge|dcAB cAGF| EGG2 gdfd|ecAG FAcf|ecc2 gceg|dcAB cAGF| EFGE FAcA|GFDF ECC:|',
    '|CEDC A,CG,A,|CDEC DCA,G,|CEGE FEDC| A,DDC DAGF|EGG2 DCEC|A,A,CD CA,G,A,|CEDC A,G,G,A,| C3E D2:||:GA|cAA2 cAGA|cAGE CDEG| cAGE CDEC|D3E DCA,G,|C,D,E,G, A,A,G,E,|A,CE,G, CDEG| cAGE DA,CD|E2C2 C2:|',
    'c2ec GECE|G2FA G2EG|A2fA fAAG| Addc B2AB|c2ec GECE|G2FA G2EG|A/2B/2cfd cAGE|D2DE C3:|D|E2EG EFGF|EGAB AGAB| cedc ABBG|BcdB GAGF|E2EE FGFE|FGAB cBAG| ABAG cGEC|D2CD C3:|',
    'CDEC DCB,A,|G,CC2 A,CC2|G,A,CD EFGc| ADD2 DCA,B,|CDC2 A,CG,2|G,CC2 DCB,D|EAA2 G2EC| B,CDB, C2:||:AB|cAcA AGEG|GEE2 CDDC| BcAF G2AB|cdcA G2AB|cAA2 GEE2|cGEC DCA,2| G,B,DE AABG|cAGE C2:|',
    'edcG EGFG|FDED DCEF|GA(3GFE FADF| GABc d2cd|edcG EFFG|FDED DGED|GABG cAGE| FAGB c2:||:(3GAB|cGeG cGeG|fefa gece| fafa afde|fefa gfed|cGeG ceGe|fede c2c\'a| gfed cAGA|BAGB c2:|',
    'DAA|AddG cAGE|DdAG dDD2|AddG cAGA| EDCE Ddc2|dddG cAGd|DAAG DDDG|Adde cAGE|1 GAGE DFDE:||2GAGE DDDd|edd2 AGEG|AFF2 GEE2| ecc2 AGEG|^FAGE D4|Bdd2 AGEG|AEE2 ADF2| Adec\' eddc|1Acde fddf:||2Adde fdcB|',
    'G,CEF GEGE|FEDC B,G,A,B,|C2EC GEFD| EDCB, CA,G,F,|E,G,CE FDEF|GEFD ECG,C|C/2B,/2CDE FEDC|B,G,B,D C3:||:E|GcBd cecA|GAGF EDCE| GABc dBcA|dBGE DAGA|Gced cBcA|GAGF EDCE| CDEG FEDC|DEDB, C3:|',
    'ADD2 ADD2|CEDE GccB|ADD2 AEDC| B,DAB c2BG|ADD2 ADD2|CDEG c2Bc|dcde fdBc| dcBA GEFE|DEFG ABcA|GABc defe|dcBA GFEF| GABG FcAB|DEFG ABcd|cABc defe|dBcA BGAF| GABG AFGA|',
]

# %%
def clean(s):
    """ Remove unwanted chars"""
    bad_chars = '|: 1>()/z_=<^'
    for c in bad_chars: 
        s = s.replace(c, "")
    return s

def remove_nums(s):
    """ Explicitly convert numbers to chars"""
    new_s = []
    temp = s[0]
    for i in range(1, len(s)):
        if s[i].isalpha():
            new_s.append(temp)
            temp = s[i]
        elif s[i].isdigit():
            temp_arr = [temp]*(int(s[i]))
            new_s.extend(temp_arr)
            temp = ''
        else:
            temp += s[i]
    return new_s

def convert_8ths_to_16ths(lst):
    new_lst = []
    for x in lst:
        if x == '':
            continue
        new_lst.append(x)
        new_lst.append(x)
    return new_lst
    
def convert_to_DMaj(s):
    """ Convert C-Major to D-Major """
    c_to_d = {
        'C':'D',
        'D':'E',
        'E':'F',
        'F':'G',
        'G':'a',
        'A':'B',
        'B':'C',
        'c':'d',
        'd':'e',
        'e':'f',
        'f':'g',
        'g':'a\'',
        'a':'b',
        'b':'c',
        'C,':'D,',
        'D,':'E,',
        'E,':'F,',
        'F,':'G,',
        'G,':'A',
        'A,':'B,',
        'B,':'C,',
        'c\'':'d\'',
        'd\'':'e\'',
        'e\'':'f\'',
        'f\'':'g\'',
        'g\'':'a\'\'',
        'a\'':'b\'',
        'b\'':'c\'',
        
    }
    return [c_to_d[x] for x in s]
    
def convert_to_notes(song):
    """ Convert chars to midi notes"""
    chars_as_num = {
        'C,': 49,
        'D,': 50,
        'E,': 52,
        'F,': 54,
        'G,': 55,
        'A,': 57,
        'B,': 59,
        'C': 61,
        'D': 62,
        'E': 64,
        'F': 66,
        'G': 67,
        'A': 69,
        'B': 71,
        'c': 73,
        'd': 74,
        'e': 76,
        'f': 78,
        'g': 79,
        'a': 81,
        'b': 83,
        'c\'': 85,
        'd\'': 86,
        'e\'': 88,
        'f\'': 90,
        'g\'': 91,
        'a\'': 93,
        'b\'': 95,
    }
    return [chars_as_num[x] for x in song]

# %%
import numpy as np

def process(all_songs):
    """ Do the entire process - only keep songs that are 64 in length"""
    vectors = []
    for song in all_songs:
        updated_song = convert_to_notes(convert_to_DMaj(convert_8ths_to_16ths(remove_nums(clean(song)))))
        if len(updated_song) > 250 and len(updated_song) < 260:
            vectors.append(updated_song)
    return np.array(vectors)

# %%
lst = process(songs)
print (lst.shape)
# Out:
# (25,)

# %%
np.save('./../Experiments_Data/folkRnn_data',lst)
